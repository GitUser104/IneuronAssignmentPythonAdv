# %%
#Question1
'''
Probability is  a mathematical funtion that describes the probability of different 
possible value of a variable.
We cannot truly predict an outcome but given the probability distribution of a data
we can predict the chances of an event happening. 
'''

# %%
#Question2
'''
Yes true random events are events generated by naturally random events and are not 
based on algorithm which means all the events cannot be predicted even if the root 
event is known whereas pseudo random events are those whicha are generated by an
algorithm and if the root event is known the futher events becomes predictable.

Pseuorandom numbers are considered good enough because they are deterministic 
in nature i.e. we can know the algorithm bephind this and they mimic unpedictable 
bbehaviour like true random numbers.
'''

# %%
#Question3
'''
The two main factors that influence the behaviour of normal distribution are 
mean and the standard deviation. The mean determines the location of center of
the graph and the standard deviation determines the height and width of the 
graph.
'''

# %%
#QUestion4
'''
There are many examples which follow a normal distribution in real world for example 
height of person, blood pressure, IQ scores etc.
'''

# %%
#Question5
'''
Assuming for a short duration we will have a small sample size then the curve will
be skewed on one side and as the sample size or trials grow the mean gets narrower
which means that curve becomes thinner.
'''

# %%
#Question6
'''
random.shuffle is used to shuffle list objects.
'''

# %%
#Question7
'''
The general category of funtions in math module is as follows:-

-> Constants 

->Trigonometric functions

->Special functions

->HYperbolic functions

->Power and logarithmic functions

->Number-theoretic and representation functions
'''
# Out:
# '\nThe general category of funtions in math module is as follows:-\n\n-> Constants \n\n->Trigonometric functions\n\n->Special functions\n\n->HYperbolic functions\n\n->Power and logarithmic functions\n\n->Number-theoretic and representation functions\n'

# %%
#Question8
'''
The logarithms can be said as inverse of exponentiations i.e. they are used to 
remove the exponentation from numbers.
'''

# %%
#Question9
'''
The three logarithmic funtion supported by python are :-

math.log(x[, base])

math.log1p(x)

math.log10(x)

there is additonal logarithmic funtion with base 2 -> math.log2(x) which returns more
accurate values than math.log(x,[2])
'''
